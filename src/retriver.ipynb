# %% [markdown]
# # Library

# %%
import arxiv, os, requests

# %% [markdown]
# ### arxiv q-fin finance topic
# - `q-fin.RM`    Risk Management
# - `q-fin.CP`    Computational Finance
# - `q-fin.ST`    Statistical Finance
# - `q-fin.TR`    Trading and Market Microstructure
# - `q-fin.EC`    Economics
# - `q-fin.GN`    General Finance
# - `q-fin.MF`	Mathematical Finance
# - `q-fin.PM`	Portfolio Management
# - `q-fin.PR`	Pricing of Securities

# %%
def download_pdfs(pdf_links, download_folder="documents", filename = ""):
    # Create the download folder if it doesn't already exist.
    if not os.path.exists(download_folder):
        os.makedirs(download_folder)
        print(f"Created directory: {download_folder}")

    url = pdf_links
    try:
        response = requests.get(url, stream=True)
        # Raise an exception for bad status codes (4xx or 5xx)
        response.raise_for_status()

        # Extract the filename from the URL
        # filename = os.path.join(download_folder, url.split("/")[-1])
        filename = os.path.join(download_folder, filename+'.pdf')

        # Save the content to a local file
        with open(filename, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        print(f"Successfully downloaded: {filename}")

    except requests.exceptions.RequestException as e:
        print(f"Error downloading {url}: {e}")
    except Exception as e:
        print(f"An unexpected error occurred for {url}: {e}")

# %% [markdown]
# # Arxiv finance retriver

# %%
#API connect
client = arxiv.Client()
#search
search = arxiv.Search(
    query=f"cat:q-fin*", #q-fin is finance topic
    max_results=20,
    sort_by=arxiv.SortCriterion.SubmittedDate #Date sort
)

# %%
results = client.results(search)
for result in client.results(search):
    print(f"📄 Title: {result.title}")
    # print(f"   ➡️ Primary Category: {result.primary_category}") 
    # This is the full list of all categories ("subqueries")
    print(f"   🏷️ All Categories (Subqueries): {result.categories}")
    print(f"   🔗 PDF Link: {result.pdf_url}")
    for categorie in result.categories:
        if('q-fin' not in categorie): continue
        download_folder = f"../data/finpaper/{categorie}/"
        download_pdfs(pdf_links=result.pdf_url, download_folder=download_folder, filename=result.title)
    print("-" * 30)
# Out:
# 📄 Title: Disaster Risk Financing through Taxation: A Framework for Regional Participation in Collective Risk-Sharing
#    🏷️ All Categories (Subqueries): ['econ.TH', 'q-fin.RM']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.18895v1
# Created directory: ../data/finpaper/q-fin.RM/
# Successfully downloaded: ../data/finpaper/q-fin.RM/Disaster Risk Financing through Taxation: A Framework for Regional Participation in Collective Risk-Sharing.pdf
# ------------------------------
# 📄 Title: The Theory of Economic Complexity
#    🏷️ All Categories (Subqueries): ['econ.GN', 'q-fin.EC']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.18829v1
# Created directory: ../data/finpaper/q-fin.EC/
# Successfully downloaded: ../data/finpaper/q-fin.EC/The Theory of Economic Complexity.pdf
# ------------------------------
# 📄 Title: An AI-powered Tool for Central Bank Business Liaisons: Quantitative Indicators and On-demand Insights from Firms
#    🏷️ All Categories (Subqueries): ['econ.GN', 'q-fin.EC']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.18505v1
# Successfully downloaded: ../data/finpaper/q-fin.EC/An AI-powered Tool for Central Bank Business Liaisons: Quantitative Indicators and On-demand Insights from Firms.pdf
# ------------------------------
# 📄 Title: American options valuation in time-dependent jump-diffusion models via integral equations and characteristic functions
#    🏷️ All Categories (Subqueries): ['q-fin.PR', 'q-fin.CP', 'q-fin.MF']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.18210v1
# Created directory: ../data/finpaper/q-fin.PR/
# Successfully downloaded: ../data/finpaper/q-fin.PR/American options valuation in time-dependent jump-diffusion models via integral equations and characteristic functions.pdf
# Created directory: ../data/finpaper/q-fin.CP/
# Successfully downloaded: ../data/finpaper/q-fin.CP/American options valuation in time-dependent jump-diffusion models via integral equations and characteristic functions.pdf
# Created directory: ../data/finpaper/q-fin.MF/
# Successfully downloaded: ../data/finpaper/q-fin.MF/American options valuation in time-dependent jump-diffusion models via integral equations and characteristic functions.pdf
# ------------------------------
# 📄 Title: Causal Interventions in Bond Multi-Dealer-to-Client Platforms
#    🏷️ All Categories (Subqueries): ['q-fin.TR']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.18147v1
# Created directory: ../data/finpaper/q-fin.TR/
# Successfully downloaded: ../data/finpaper/q-fin.TR/Causal Interventions in Bond Multi-Dealer-to-Client Platforms.pdf
# ------------------------------
# 📄 Title: Predicting Stock Market Crash with Bayesian Generalised Pareto Regression
#    🏷️ All Categories (Subqueries): ['q-fin.ST', 'stat.AP', 'stat.ML', '62K05, 05B0530']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.17549v1
# Created directory: ../data/finpaper/q-fin.ST/
# Successfully downloaded: ../data/finpaper/q-fin.ST/Predicting Stock Market Crash with Bayesian Generalised Pareto Regression.pdf
# ------------------------------
# 📄 Title: Empirical Models of the Time Evolution of SPX Option Prices
#    🏷️ All Categories (Subqueries): ['q-fin.PR', 'q-fin.CP']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.17511v1
# Successfully downloaded: ../data/finpaper/q-fin.PR/Empirical Models of the Time Evolution of SPX Option Prices.pdf
# Successfully downloaded: ../data/finpaper/q-fin.CP/Empirical Models of the Time Evolution of SPX Option Prices.pdf
# ------------------------------
# 📄 Title: Social Group Bias in AI Finance
#    🏷️ All Categories (Subqueries): ['econ.GN', 'q-fin.EC']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.17490v1
# Successfully downloaded: ../data/finpaper/q-fin.EC/Social Group Bias in AI Finance.pdf
# ------------------------------
# 📄 Title: A new equilibrium: COVID-19 lockdowns and WFH persistence
#    🏷️ All Categories (Subqueries): ['econ.GN', 'q-fin.EC']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.16671v1
# Successfully downloaded: ../data/finpaper/q-fin.EC/A new equilibrium: COVID-19 lockdowns and WFH persistence.pdf
# ------------------------------
# 📄 Title: Optimal Regulation and Investment Incentives in Financial Networks
#    🏷️ All Categories (Subqueries): ['econ.GN', 'q-fin.EC']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.16648v1
# Successfully downloaded: ../data/finpaper/q-fin.EC/Optimal Regulation and Investment Incentives in Financial Networks.pdf
# ------------------------------
# 📄 Title: Social Media Can Reduce Misinformation When Public Scrutiny is High
#    🏷️ All Categories (Subqueries): ['econ.GN', 'q-fin.EC']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.16355v1
# Successfully downloaded: ../data/finpaper/q-fin.EC/Social Media Can Reduce Misinformation When Public Scrutiny is High.pdf
# ------------------------------
# 📄 Title: Artificial Intelligence, Lean Startup Method, and Product Innovations
#    🏷️ All Categories (Subqueries): ['econ.GN', 'q-fin.EC']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.16334v1
# Successfully downloaded: ../data/finpaper/q-fin.EC/Artificial Intelligence, Lean Startup Method, and Product Innovations.pdf
# ------------------------------
# 📄 Title: Pricing under the Benchmark Approach
#    🏷️ All Categories (Subqueries): ['q-fin.MF', 'q-fin.GN', '62P05, 60G35, 62P20', 'G.3']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.16264v1
# Successfully downloaded: ../data/finpaper/q-fin.MF/Pricing under the Benchmark Approach.pdf
# Created directory: ../data/finpaper/q-fin.GN/
# Successfully downloaded: ../data/finpaper/q-fin.GN/Pricing under the Benchmark Approach.pdf
# ------------------------------
# 📄 Title: On Design of Representative Distributionally Robust Formulations for Evaluation of Tail Risk Measures
#    🏷️ All Categories (Subqueries): ['q-fin.RM', 'math.PR', 'stat.ME', 'stat.ML']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.16230v1
# Successfully downloaded: ../data/finpaper/q-fin.RM/On Design of Representative Distributionally Robust Formulations for Evaluation of Tail Risk Measures.pdf
# ------------------------------
# 📄 Title: AI is the Strategy: From Agentic AI to Autonomous Business Models onto Strategy in the Age of AI
#    🏷️ All Categories (Subqueries): ['cs.CY', 'econ.GN', 'q-fin.EC']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.17339v1
# Successfully downloaded: ../data/finpaper/q-fin.EC/AI is the Strategy: From Agentic AI to Autonomous Business Models onto Strategy in the Age of AI.pdf
# ------------------------------
# 📄 Title: Long Coalition Leads to Shrink? The Roles of Tipping and Technology-Sharing in Climate Clubs
#    🏷️ All Categories (Subqueries): ['econ.GN', 'q-fin.EC']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.16162v1
# Successfully downloaded: ../data/finpaper/q-fin.EC/Long Coalition Leads to Shrink? The Roles of Tipping and Technology-Sharing in Climate Clubs.pdf
# ------------------------------
# 📄 Title: The Economic Value of Depth
#    🏷️ All Categories (Subqueries): ['econ.GN', 'q-fin.EC']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.15354v1
# Successfully downloaded: ../data/finpaper/q-fin.EC/The Economic Value of Depth.pdf
# ------------------------------
# 📄 Title: Conditional Generative Modeling for Enhanced Credit Risk Management in Supply Chain Finance
#    🏷️ All Categories (Subqueries): ['cs.LG', 'q-fin.RM']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.15305v1
# Successfully downloaded: ../data/finpaper/q-fin.RM/Conditional Generative Modeling for Enhanced Credit Risk Management in Supply Chain Finance.pdf
# ------------------------------
# 📄 Title: How does online shopping affect offline price sensitivity?
#    🏷️ All Categories (Subqueries): ['econ.GN', 'q-fin.EC']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.15103v1
# Successfully downloaded: ../data/finpaper/q-fin.EC/How does online shopping affect offline price sensitivity?.pdf
# ------------------------------
# 📄 Title: Identifying economic narratives in large text corpora -- An integrated approach using Large Language Models
#    🏷️ All Categories (Subqueries): ['econ.GN', 'cs.CL', 'q-fin.EC']
#    🔗 PDF Link: http://arxiv.org/pdf/2506.15041v1
# Successfully downloaded: ../data/finpaper/q-fin.EC/Identifying economic narratives in large text corpora -- An integrated approach using Large Language Models.pdf
# ------------------------------
